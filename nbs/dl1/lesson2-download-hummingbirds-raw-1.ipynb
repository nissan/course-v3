# %% [markdown]
# # Creating your own dataset from Google Images - Hummingbird Species of Trinidad and Tobago
# *by: Nissan Dookeran based on the lesson2_download notebook*
#
# **Original notebook by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)**

# %% [markdown]
# I use Lesson 2 notebook to see how to easily create an image dataset through Google Images for 9 of the species of hummingbirds in Trinidad and Tobago.

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# I followed the instructions as given:
#
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'ruby_topaz'
file = 'urls_ruby_topaz.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:18<00:00]
#     </div>
# Error https://c8.alamy.com/comp/DXRND7/ruby-topaz-hummingbird-chrysolampus-mosquitus-hovering-while-feeding-DXRND7.jpg 'content-length'
# Error https://c8.alamy.com/comp/HMF8R0/male-ruby-topaz-hummingbird-chrysolampis-mosquitus-trinidad-tobago-HMF8R0.jpg 'content-length'
# ...

# %%
folder = 'long_billed_starthroat'
file = 'urls_long_billed_starthroat.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:13<00:00]
#     </div>
# Error https://c8.alamy.com/comp/BFJ1RF/long-billed-starthroat-heliomaster-longirostris-feeding-at-a-flower-BFJ1RF.jpg 'content-length'
# Error https://c8.alamy.com/comp/EE0GWA/long-billed-starthroat-hummingbird-heliomaster-longirostris-single-EE0GWA.jpg 'content-length'
# ...

# %%
folder = 'black_throated_mango'
file = 'urls_black_throated_mango.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:21<00:00]
#     </div>
# Error http://www.canopytower.com/images/Black-throated_Mango_11_600_US.jpg 'content-length'
# Error http://www.canopytower.com/images/Black-throated_Mango_2_600_US.jpg 'content-length'
# Error https://s1.stabroeknews.com/images/2017/11/Black-throated-Mango.jpg 'content-length'
# ...

# %%
folder = 'tufted_coquette'
file = 'urls_tufted_coquette.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:11<00:00]
#     </div>
# Error http://www.kaieteurnewsonline.com/images/2009/07/tuft.jpg 'content-length'
# Error https://c8.alamy.com/comp/E5516F/tufted-coquette-lophornis-ornatus-adult-male-perched-on-flowerhead-E5516F.jpg 'content-length'
# ...

# %%
folder = 'green_throated_mango'
file = 'urls_green_throated_mango.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:08<00:00]
#     </div>
# Error http://www.canopytower.com/images/Black-throated_Mango_11_600_US.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1109910482407518 'content-length'
# ...

# %%
folder = 'blue_chinned_sapphire'
file = 'urls_blue_chinned_sapphire.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:22<00:00]
#     </div>
# Error x-raw-image:///10e4eb83f6f47ac426641199790e27cbdcac3ea4c996f9aa47de701c50ce8723 No connection adapters were found for 'x-raw-image:///10e4eb83f6f47ac426641199790e27cbdcac3ea4c996f9aa47de701c50ce8723'
# ...

# %%
folder = 'blue_tailed_emerald'
file = 'urls_blue_tailed_emerald.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=150)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='150' class='' max='150', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:06<00:00]
#     </div>
# Error https://c7.alamy.com/comp/X1X5AM/blue-tailed-emerald-chlorostilbon-mellisugus-flying-while-feeding-at-a-flower-in-peru-X1X5AM.jpg 'content-length'
# Error https://c8.alamy.com/comp/E1W2D3/blue-tailed-emerald-chlorostilbon-mellisugus-flying-while-feeding-E1W2D3.jpg 'content-length'
# ...

# %%
folder = 'brown_violetear'
file = 'urls_brown_violetear.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=150)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='150' class='' max='150', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:06<00:00]
#     </div>
# Error x-raw-image:///178588728cc8189513f5fc2fe6c0deab112b8e0f881f2e6443ad4e4d06e65bd0 No connection adapters were found for 'x-raw-image:///178588728cc8189513f5fc2fe6c0deab112b8e0f881f2e6443ad4e4d06e65bd0'
# ...

# %%
folder = 'copper_rumped'
file = 'urls_copper_rumped.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:10<00:00]
#     </div>
# Error https://c8.alamy.com/comp/X41FFY/copper-rumped-hummingbird-amazilia-tobaci-erythronotus-flying-while-feeding-at-a-flower-in-trinidad-and-tobago-X41FFY.jpg 'content-length'
# Error http://c8.alamy.com/comp/M0CXMD/copper-rumped-hummingbird-amazilia-tobaci-M0CXMD.jpg 'content-length'
# ...

# %%
folder = 'white_necked_jacobin'
file = 'urls_white_necked_jacobin.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 01:25<00:00]
#     </div>
# Error http://c8.alamy.com/comp/X2TDCC/a-white-necked-jacobin-hummingbird-florisuga-mellivora-in-costa-rica-X2TDCC.jpg 'content-length'
# Error https://c8.alamy.com/comp/HFWKJB/white-necked-jacobin-hummingbird-HFWKJB.jpg 'content-length'
# ...

# %%
folder = 'white_tailed_sabrewing'
file = 'urls_white_tailed_sabrewing.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Error https://c8.alamy.com/comp/ECXN9G/white-tailed-sabrewing-campylopterus-ensipennis-hummingbird-single-ECXN9G.jpg 'content-length'
# Error https://c8.alamy.com/comp/M0CXNT/white-tailed-sabrewing-campylopterus-ensipennis-M0CXNT.jpg 'content-length'
# ...

# %%
folder = 'white_tailed_goldenthroat'
file = 'urls_white_tailed_goldenthroat.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 01:54<00:00]
#     </div>
# ...

# %%
folder = 'rufous_breasted_hermit'
file = 'urls_rufous_breasted_hermit.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 01:33<00:00]
#     </div>
# Error https://www.hbw.com/sites/default/files/styles/ibc_1k/public/ibc/p/hermit_new_redigerad-3.jpg?itok=Q-LMGaat 'content-length'
# Error https://c7.alamy.com/comp/X62EW9/rufous-breasted-hermit-glaucis-hirsutus-insularum-flying-while-feeding-at-a-flower-in-trinidad-and-tobago-X62EW9.jpg 'content-length'
# ...

# %%
folder = 'little_hermit'
file = 'urls_little_hermit.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:55<00:00]
#     </div>
# Error http://www.robertofabbri-wildlife.com/wp-content/gallery/birds-in-flight/little_hermit_hummingbird_2007_0027.jpg 'content-length'
# Error https://c8.alamy.com/comp/F0P6CH/little-hermit-taken-at-el-chorro-del-macho-waterfall-el-valle-de-anton-F0P6CH.jpg 'content-length'
# ...

# %%
folder = 'green_hermit'
file = 'urls_green_hermit.txt'
path = Path('data/hummingbirds')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 01:37<00:00]
#     </div>
# Error https://cbsnews3.cbsistatic.com/hub/i/r/2016/02/09/124db976-6d3e-4eb1-8ada-33988fbad61e/thumbnail/1200x630/7866e80418595bddd0f0d4501398cd8c/gettyimages-507851950.jpg 'content-length'
# Error https://c8.alamy.com/comp/EEB3HF/green-hermit-hummingbird-at-heliconia-flower-EEB3HF.jpg 'content-length'
# ...

# %%
classes = ['ruby_topaz',
           'copper_rumped',
           'long_billed_starthroat',
           'brown_violetear',
           'blue_tailed_emerald',
           'blue_chinned_sapphire', 
           'green_throated_mango', 
           'tufted_coquette', 
           'black_throated_mango',
           'white_necked_jacobin',
           'white_tailed_sabrewing',
           'white_tailed_goldenthroat',
           'rufous_breasted_hermit',
           'little_hermit',
           'green_hermit'
          ]

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# ruby_topaz
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='194' class='' max='194', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [194/194 00:00<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/hummingbirds/ruby_topaz/00000003.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/hummingbirds/ruby_topaz/00000198.jpg'
# ...

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['black_throated_mango',
#  'blue_chinned_sapphire',
#  'blue_tailed_emerald',
#  'brown_violetear',
#  'copper_rumped',
#  'green_throated_mango',
#  'long_billed_starthroat',
#  'ruby_topaz',
#  'tufted_coquette']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black_throated_mango',
#   'blue_chinned_sapphire',
#   'blue_tailed_emerald',
#   'brown_violetear',
#   'copper_rumped',
#   'green_throated_mango',
#   'long_billed_starthroat',
#   'ruby_topaz',
#   'tufted_coquette'],
#  9,
#  1207,
#  331)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(8)
# Out:
# Total time: 02:38
# epoch  train_loss  valid_loss  error_rate
# 1      2.333454    1.726202    0.561934    (00:19)
# 2      1.817333    1.367800    0.465257    (00:19)
# 3      1.467729    1.296390    0.429003    (00:19)
# 4      1.226823    1.274136    0.432024    (00:19)
# 5      1.053560    1.227940    0.407855    (00:20)
# 6      0.915804    1.226127    0.410876    (00:20)
# 7      0.817056    1.222592    0.407855    (00:19)
# 8      0.745230    1.216261    0.407855    (00:19)

# %%
learn.save('stage-1')

# %%
learn.load('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-4,1e-3))
# Out:
# Total time: 03:35
# epoch  train_loss  valid_loss  error_rate
# 1      0.597267    1.204534    0.407855    (00:21)
# 2      0.521106    1.341956    0.422961    (00:21)
# 3      0.494833    1.613458    0.419940    (00:21)
# 4      0.504582    1.529027    0.419940    (00:22)
# 5      0.480012    1.508638    0.435045    (00:20)
# 6      0.406417    1.276324    0.389728    (00:22)
# 7      0.338109    1.368917    0.401813    (00:21)
# 8      0.287059    1.385188    0.377643    (00:20)
# 9      0.241106    1.377430    0.374622    (00:21)
# 10     0.207914    1.385774    0.365559    (00:22)

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5)

# %%
interp.most_confused()
# Out:
# [('green_throated_mango', 'black_throated_mango', 26),
#  ('black_throated_mango', 'green_throated_mango', 19),
#  ('blue_chinned_sapphire', 'blue_tailed_emerald', 10),
#  ('blue_chinned_sapphire', 'copper_rumped', 5),
#  ('blue_tailed_emerald', 'blue_chinned_sapphire', 5),
#  ('copper_rumped', 'tufted_coquette', 4),
#  ('ruby_topaz', 'brown_violetear', 3),
#  ('black_throated_mango', 'blue_chinned_sapphire', 2),
#  ('black_throated_mango', 'copper_rumped', 2),
#  ('blue_chinned_sapphire', 'black_throated_mango', 2),
#  ('blue_tailed_emerald', 'ruby_topaz', 2),
#  ('brown_violetear', 'ruby_topaz', 2),
#  ('brown_violetear', 'tufted_coquette', 2),
#  ('copper_rumped', 'black_throated_mango', 2),
#  ('copper_rumped', 'blue_chinned_sapphire', 2),
#  ('copper_rumped', 'ruby_topaz', 2),
#  ('green_throated_mango', 'copper_rumped', 2),
#  ('long_billed_starthroat', 'blue_tailed_emerald', 2),
#  ('ruby_topaz', 'long_billed_starthroat', 2),
#  ('ruby_topaz', 'tufted_coquette', 2),
# ...

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `FileDeleter` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.
#
# First we need to get the file paths from our top_losses. Here's a handy function that pulls out all our top_losses:

# %%
from fastai.widgets import *

losses,idxs = interp.top_losses()
top_loss_paths = data.valid_ds.x[idxs]

# %% [markdown]
# Now we can pass in these paths to our widget.

# %%
??FileDeleter

# %%
fd = FileDeleter(file_paths=top_loss_paths)
# Out:
# ...
# Button(button_style='primary', description='Confirm', style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Confirm' to delete flagged photos and keep the rest in that row. The `File_Deleter` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses`.

# %% [markdown]
# **NOTE: In this case, the problem wasn't bad images coming it, it was that the hummingbird images coming in for a species were not of that species, which FileDeleter didn't give enough information to prune, so we will prune manually and try again in 2nd notebook**

# %% [markdown]
# ## Putting your model in production

# %%
data.classes
# Out:
# ['black_throated_mango',
#  'blue_chinned_sapphire',
#  'blue_tailed_emerald',
#  'brown_violetear',
#  'copper_rumped',
#  'green_throated_mango',
#  'long_billed_starthroat',
#  'ruby_topaz',
#  'tufted_coquette']

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
# fastai.defaults.device = torch.device('cpu')

# %%
img = open_image(path/'ruby_topaz'/'00000020.jpg')
img
# Out:
# Image (3, 735, 1024)

# %%
classes = ['black_throated_mango',
  'blue_chinned_sapphire',
  'blue_tailed_emerald',
  'brown_violetear',
  'copper_rumped',
  'green_throated_mango',
  'long_billed_starthroat',
  'ruby_topaz',
  'tufted_coquette']
data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet34)
learn.load('stage-2')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'ruby_topaz'

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)
